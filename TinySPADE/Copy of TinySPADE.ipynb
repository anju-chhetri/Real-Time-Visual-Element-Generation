# %%
# from google.colab import drive
# drive.mount('/content/drive')

# !pip install -q pytorch-lightning

# !unzip /content/drive/MyDrive/grass/datasets/train.zip -d /content/train
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/train/Output/3875_output.jpg
#  extracting: /content/train/Output/3876_output.jpg
#  extracting: /content/train/Output/3877_output.jpg
#  extracting: /content/train/Output/3878_output.jpg
#  extracting: /content/train/Output/3879_output.jpg
#  extracting: /content/train/Output/387_output.jpg
#  extracting: /content/train/Output/3880_output.jpg
#  extracting: /content/train/Output/3881_output.jpg
#  extracting: /content/train/Output/3882_output.jpg
#  extracting: /content/train/Output/3883_output.jpg
#  extracting: /content/train/Output/3884_output.jpg
#  extracting: /content/train/Output/3885_output.jpg
#  extracting: /content/train/Output/3886_output.jpg
#  extracting: /content/train/Output/3887_output.jpg
#  extracting: /content/train/Output/3888_output.jpg
#  extracting: /content/train/Output/3889_output.jpg
#  extracting: /content/train/Output/388_output.jpg
#  extracting: /content/train/Output/3890_output.jpg
#  extracting: /content/train/Output/3891_output.jpg
#  extracting: /content/train/Output/3892_output.jpg
#  extracting: /content/train/Output/3893_output.jpg
#  extracting: /content/train/Output/3894_output.jpg
#  extracting: /content/train/Output/3895_output.jpg
#  extracting: /content/train/Output/3896_output.jpg
#  extracting: /content/train/Output/3897_output.jpg
#  extracting: /content/train/Output/3898_output.jpg
#  extracting: /content/train/Output/3899_output.jpg
#  extracting: /content/train/Output/389_output.jpg
#  extracting: /content/train/Output/38_output.jpg
#  extracting: /content/train/Output/3900_output.jpg
#  extracting: /content/train/Output/3901_output.jpg
#  extracting: /content/train/Output/3902_output.jpg
#  extracting: /content/train/Output/3903_output.jpg
#  extracting: /content/train/Output/3904_output.jpg
#  extracting: /content/train/Output/3905_output.jpg
#  extracting: /content/train/Output/3906_output.jpg
#  extracting: /content/train/Output/3907_output.jpg
#  extracting: /content/train/Output/3908_output.jpg
#  extracting: /content/train/Output/3909_output.jpg
#  extracting: /content/train/Output/390_output.jpg
#  extracting: /content/train/Output/3910_output.jpg
#  extracting: /content/train/Output/3911_output.jpg
#  extracting: /content/train/Output/3912_output.jpg
#  extracting: /content/train/Output/3913_output.jpg
#  extracting: /content/train/Output/3914_output.jpg
#  extracting: /content/train/Output/3915_output.jpg
#  extracting: /content/train/Output/3916_output.jpg
#  extracting: /content/train/Output/3917_output.jpg
#  extracting: /content/train/Output/3918_output.jpg
#  extracting: /content/train/Output/3919_output.jpg
#  extracting: /content/train/Output/391_output.jpg
#  extracting: /content/train/Output/3920_output.jpg
#  extracting: /content/train/Output/3921_output.jpg
#  extracting: /content/train/Output/3922_output.jpg
#  extracting: /content/train/Output/3923_output.jpg
#  extracting: /content/train/Output/3924_output.jpg
#  extracting: /content/train/Output/3925_output.jpg
#  extracting: /content/train/Output/3926_output.jpg
#  extracting: /content/train/Output/3927_output.jpg
#  extracting: /content/train/Output/3928_output.jpg
#  extracting: /content/train/Output/3929_output.jpg
#  extracting: /content/train/Output/392_output.jpg
#  extracting: /content/train/Output/3930_output.jpg
#  extracting: /content/train/Output/3992_output.jpg
#  extracting: /content/train/Output/3993_output.jpg
#  extracting: /content/train/Output/3994_output.jpg
#  extracting: /content/train/Output/3995_output.jpg
#  extracting: /content/train/Output/3996_output.jpg
#  extracting: /content/train/Output/3997_output.jpg
#  extracting: /content/train/Output/3998_output.jpg
#  extracting: /content/train/Output/3999_output.jpg
#  extracting: /content/train/Output/399_output.jpg
#  extracting: /content/train/Output/39_output.jpg
#  extracting: /content/train/Output/3_output.jpg
#  extracting: /content/train/Output/4000_output.jpg
#  extracting: /content/train/Output/4001_output.jpg
#  extracting: /content/train/Output/4002_output.jpg
#  extracting: /content/train/Output/4003_output.jpg
#  extracting: /content/train/Output/4004_output.jpg
#  extracting: /content/train/Output/4005_output.jpg
#  extracting: /content/train/Output/4006_output.jpg
#  extracting: /content/train/Output/4007_output.jpg
#  extracting: /content/train/Output/4008_output.jpg
#  extracting: /content/train/Output/4009_output.jpg
#  extracting: /content/train/Output/400_output.jpg
#  extracting: /content/train/Output/4010_output.jpg
#  extracting: /content/train/Output/4011_output.jpg
#  extracting: /content/train/Output/4012_output.jpg
#  extracting: /content/train/Output/4013_output.jpg
#  extracting: /content/train/Output/4014_output.jpg
#  extracting: /content/train/Output/4015_output.jpg
#  extracting: /content/train/Output/4016_output.jpg
#  extracting: /content/train/Output/4017_output.jpg
#  extracting: /content/train/Output/4018_output.jpg
#  extracting: /content/train/Output/4019_output.jpg
#  extracting: /content/train/Output/401_output.jpg
#  extracting: /content/train/Output/4020_output.jpg
#  extracting: /content/train/Output/4021_output.jpg
#  extracting: /content/train/Output/4022_output.jpg
#  extracting: /content/train/Output/4023_output.jpg
#  extracting: /content/train/Output/4024_output.jpg
#  extracting: /content/train/Output/4025_output.jpg
#  extracting: /content/train/Output/4026_output.jpg
#  extracting: /content/train/Output/4027_output.jpg
#  extracting: /content/train/Output/4028_output.jpg
#  extracting: /content/train/Output/4029_output.jpg
#  extracting: /content/train/Output/402_output.jpg
#  extracting: /content/train/Output/4030_output.jpg
#  extracting: /content/train/Output/4031_output.jpg
#  extracting: /content/train/Output/4032_output.jpg
#  extracting: /content/train/Output/4033_output.jpg
#  extracting: /content/train/Output/4034_output.jpg
#  extracting: /content/train/Output/4035_output.jpg
#  extracting: /content/train/Output/4036_output.jpg
#  extracting: /content/train/Output/4037_output.jpg
#  extracting: /content/train/Output/4038_output.jpg
#  extracting: /content/train/Output/4039_output.jpg
#  extracting: /content/train/Output/403_output.jpg
#  extracting: /content/train/Output/4040_output.jpg
#  extracting: /content/train/Output/4041_output.jpg
#  extracting: /content/train/Output/4042_output.jpg
#  extracting: /content/train/Output/4043_output.jpg
#  extracting: /content/train/Output/4044_output.jpg
#  extracting: /content/train/Output/4045_output.jpg
#  extracting: /content/train/Output/4046_output.jpg
#  extracting: /content/train/Output/4047_output.jpg
#  extracting: /content/train/Output/4048_output.jpg
#  extracting: /content/train/Output/4049_output.jpg
#  extracting: /content/train/Output/404_output.jpg
#  extracting: /content/train/Output/4050_output.jpg
#  extracting: /content/train/Output/4051_output.jpg
#  extracting: /content/train/Output/4052_output.jpg
#  extracting: /content/train/Output/4053_output.jpg
#  extracting: /content/train/Output/4054_output.jpg
#  extracting: /content/train/Output/4055_output.jpg
#  extracting: /content/train/Output/4056_output.jpg
#  extracting: /content/train/Output/4057_output.jpg
#  extracting: /content/train/Output/4058_output.jpg
#  extracting: /content/train/Output/4059_output.jpg
#  extracting: /content/train/Output/405_output.jpg
#  extracting: /content/train/Output/4060_output.jpg
#  extracting: /content/train/Output/4061_output.jpg
#  extracting: /content/train/Output/4062_output.jpg
#  extracting: /content/train/Output/4063_output.jpg
#  extracting: /content/train/Output/4064_output.jpg
#  extracting: /content/train/Output/4065_output.jpg
#  extracting: /content/train/Output/4066_output.jpg
#  extracting: /content/train/Output/4067_output.jpg
#  extracting: /content/train/Output/4068_output.jpg
#  extracting: /content/train/Output/4069_output.jpg
#  extracting: /content/train/Output/406_output.jpg
#  extracting: /content/train/Output/4070_output.jpg
#  extracting: /content/train/Output/4071_output.jpg
#  extracting: /content/train/Output/4072_output.jpg
#  extracting: /content/train/Output/4073_output.jpg
#  extracting: /content/train/Output/4074_output.jpg
#  extracting: /content/train/Output/4075_output.jpg
#  extracting: /content/train/Output/4076_output.jpg
#  extracting: /content/train/Output/4077_output.jpg
#  extracting: /content/train/Output/4078_output.jpg
#  extracting: /content/train/Output/4079_output.jpg
#  extracting: /content/train/Output/407_output.jpg
#  extracting: /content/train/Output/4080_output.jpg
#  extracting: /content/train/Output/4081_output.jpg
#  extracting: /content/train/Output/4082_output.jpg
#  extracting: /content/train/Output/4083_output.jpg
#  extracting: /content/train/Output/4084_output.jpg
#  extracting: /content/train/Output/4085_output.jpg
#  extracting: /content/train/Output/4086_output.jpg
#  extracting: /content/train/Output/4087_output.jpg
#  extracting: /content/train/Output/4088_output.jpg
#  extracting: /content/train/Output/4089_output.jpg
#  extracting: /content/train/Output/408_output.jpg
#  extracting: /content/train/Output/4090_output.jpg
#  extracting: /content/train/Output/4091_output.jpg
#  extracting: /content/train/Output/4092_output.jpg
#  extracting: /content/train/Output/4093_output.jpg
#  extracting: /content/train/Output/4094_output.jpg
#  extracting: /content/train/Output/4095_output.jpg
#  extracting: /content/train/Output/4096_output.jpg
#  extracting: /content/train/Output/4097_output.jpg
#  extracting: /content/train/Output/4098_output.jpg
#  extracting: /content/train/Output/4099_output.jpg
#  extracting: /content/train/Output/409_output.jpg
#  extracting: /content/train/Output/40_output.jpg
#  extracting: /content/train/Output/4100_output.jpg
#  extracting: /content/train/Output/4101_output.jpg
#  extracting: /content/train/Output/4102_output.jpg
#  extracting: /content/train/Output/4103_output.jpg
#  extracting: /content/train/Output/4104_output.jpg
#  extracting: /content/train/Output/4105_output.jpg
#  extracting: /content/train/Output/4106_output.jpg
#  extracting: /content/train/Output/4107_output.jpg
#  extracting: /content/train/Output/4108_output.jpg
#  extracting: /content/train/Output/4109_output.jpg
#  extracting: /content/train/Output/410_output.jpg
#  extracting: /content/train/Output/4110_output.jpg
#  extracting: /content/train/Output/4111_output.jpg
#  extracting: /content/train/Output/4112_output.jpg
#  extracting: /content/train/Output/4113_output.jpg
#  extracting: /content/train/Output/4114_output.jpg
#  extracting: /content/train/Output/4115_output.jpg
#  extracting: /content/train/Output/4116_output.jpg
#  extracting: /content/train/Output/4117_output.jpg
#  extracting: /content/train/Output/4118_output.jpg
#  extracting: /content/train/Output/4119_output.jpg
#  extracting: /content/train/Output/411_output.jpg
#  extracting: /content/train/Output/4120_output.jpg
#  extracting: /content/train/Output/4121_output.jpg
#  extracting: /content/train/Output/4122_output.jpg
#  extracting: /content/train/Output/4123_output.jpg
#  extracting: /content/train/Output/4124_output.jpg
#  extracting: /content/train/Output/4125_output.jpg
#  extracting: /content/train/Output/4126_output.jpg
#  extracting: /content/train/Output/4127_output.jpg
#  extracting: /content/train/Output/4128_output.jpg
#  extracting: /content/train/Output/4129_output.jpg
#  extracting: /content/train/Output/412_output.jpg
#  extracting: /content/train/Output/4130_output.jpg
#  extracting: /content/train/Output/4131_output.jpg
#  extracting: /content/train/Output/4132_output.jpg
#  extracting: /content/train/Output/4133_output.jpg
#  extracting: /content/train/Output/4134_output.jpg
#  extracting: /content/train/Output/4135_output.jpg
#  extracting: /content/train/Output/4136_output.jpg
#  extracting: /content/train/Output/4137_output.jpg
#  extracting: /content/train/Output/4138_output.jpg
#  extracting: /content/train/Output/4139_output.jpg
#  extracting: /content/train/Output/413_output.jpg
#  extracting: /content/train/Output/4140_output.jpg
#  extracting: /content/train/Output/4141_output.jpg
#  extracting: /content/train/Output/4142_output.jpg
#  extracting: /content/train/Output/4143_output.jpg
#  extracting: /content/train/Output/4144_output.jpg
#  extracting: /content/train/Output/4145_output.jpg
#  extracting: /content/train/Output/4146_output.jpg
#  extracting: /content/train/Output/4147_output.jpg
#  extracting: /content/train/Output/4148_output.jpg
#  extracting: /content/train/Output/4149_output.jpg
#  extracting: /content/train/Output/414_output.jpg
#  extracting: /content/train/Output/4150_output.jpg
#  extracting: /content/train/Output/4151_output.jpg
#  extracting: /content/train/Output/4152_output.jpg
#  extracting: /content/train/Output/4153_output.jpg
#  extracting: /content/train/Output/4154_output.jpg
#  extracting: /content/train/Output/4155_output.jpg
#  extracting: /content/train/Output/4156_output.jpg
#  extracting: /content/train/Output/4157_output.jpg
#  extracting: /content/train/Output/4158_output.jpg
#  extracting: /content/train/Output/4159_output.jpg
#  extracting: /content/train/Output/415_output.jpg
#  extracting: /content/train/Output/4160_output.jpg
#  extracting: /content/train/Output/4161_output.jpg
#  extracting: /content/train/Output/4162_output.jpg
#  extracting: /content/train/Output/4163_output.jpg
#  extracting: /content/train/Output/4164_output.jpg
#  extracting: /content/train/Output/4165_output.jpg
#  extracting: /content/train/Output/4166_output.jpg
#  extracting: /content/train/Output/4167_output.jpg
#  extracting: /content/train/Output/4168_output.jpg
#  extracting: /content/train/Output/4169_output.jpg
#  extracting: /content/train/Output/416_output.jpg
#  extracting: /content/train/Output/4170_output.jpg
#  extracting: /content/train/Output/4171_output.jpg
#  extracting: /content/train/Output/4172_output.jpg
#  extracting: /content/train/Output/4173_output.jpg
#  extracting: /content/train/Output/4174_output.jpg
#  extracting: /content/train/Output/4175_output.jpg
#  extracting: /content/train/Output/4176_output.jpg
#  extracting: /content/train/Output/4177_output.jpg
#  extracting: /content/train/Output/4178_output.jpg
#  extracting: /content/train/Output/4179_output.jpg
#  extracting: /content/train/Output/417_output.jpg
#  extracting: /content/train/Output/4180_output.jpg
#  extracting: /content/train/Output/4181_output.jpg
#  extracting: /content/train/Output/4182_output.jpg
#  extracting: /content/train/Output/4183_output.jpg
#  extracting: /content/train/Output/4184_output.jpg
#  extracting: /content/train/Output/4185_output.jpg
#  extracting: /content/train/Output/4186_output.jpg
#  extracting: /content/train/Output/4187_output.jpg
#  extracting: /content/train/Output/4188_output.jpg
#  extracting: /content/train/Output/4189_output.jpg
#  extracting: /content/train/Output/418_output.jpg
#  extracting: /content/train/Output/4190_output.jpg
#  extracting: /content/train/Output/4191_output.jpg
#  extracting: /content/train/Output/4192_output.jpg
#  extracting: /content/train/Output/4193_output.jpg
#  extracting: /content/train/Output/4194_output.jpg
#  extracting: /content/train/Output/4195_output.jpg
#  extracting: /content/train/Output/4196_output.jpg
#  extracting: /content/train/Output/4197_output.jpg
#  extracting: /content/train/Output/4198_output.jpg
#  extracting: /content/train/Output/4199_output.jpg
#  extracting: /content/train/Output/419_output.jpg
#  extracting: /content/train/Output/41_output.jpg
#  extracting: /content/train/Output/4200_output.jpg
#  extracting: /content/train/Output/4201_output.jpg
#  extracting: /content/train/Output/4202_output.jpg
#  extracting: /content/train/Output/4203_output.jpg
#  extracting: /content/train/Output/4204_output.jpg
#  extracting: /content/train/Output/4205_output.jpg
#  extracting: /content/train/Output/4206_output.jpg
#  extracting: /content/train/Output/4207_output.jpg
#  extracting: /content/train/Output/4208_output.jpg
#  extracting: /content/train/Output/4209_output.jpg
#  extracting: /content/train/Output/420_output.jpg
#  extracting: /content/train/Output/4210_output.jpg
#  extracting: /content/train/Output/4211_output.jpg
#  extracting: /content/train/Output/4212_output.jpg
#  extracting: /content/train/Output/4213_output.jpg
#  extracting: /content/train/Output/4214_output.jpg
#  extracting: /content/train/Output/4215_output.jpg
#  extracting: /content/train/Output/4216_output.jpg
#  extracting: /content/train/Output/4217_output.jpg
#  extracting: /content/train/Output/4218_output.jpg
#  extracting: /content/train/Output/4219_output.jpg
#  extracting: /content/train/Output/421_output.jpg
#  extracting: /content/train/Output/4220_output.jpg
#  extracting: /content/train/Output/4221_output.jpg
#  extracting: /content/train/Output/4222_output.jpg
#  extracting: /content/train/Output/4223_output.jpg
#  extracting: /content/train/Output/4224_output.jpg
#  extracting: /content/train/Output/4225_output.jpg
#  extracting: /content/train/Output/4226_output.jpg
#  extracting: /content/train/Output/4227_output.jpg
#  extracting: /content/train/Output/4228_output.jpg
#  extracting: /content/train/Output/4229_output.jpg
#  extracting: /content/train/Output/422_output.jpg
#  extracting: /content/train/Output/4230_output.jpg
#  extracting: /content/train/Output/4231_output.jpg
#  extracting: /content/train/Output/4232_output.jpg
#  extracting: /content/train/Output/4233_output.jpg
#  extracting: /content/train/Output/4234_output.jpg
#  extracting: /content/train/Output/4235_output.jpg
#  extracting: /content/train/Output/4236_output.jpg
#  extracting: /content/train/Output/4237_output.jpg
#  extracting: /content/train/Output/4238_output.jpg
#  extracting: /content/train/Output/4239_output.jpg
#  extracting: /content/train/Output/423_output.jpg
#  extracting: /content/train/Output/4240_output.jpg
#  extracting: /content/train/Output/4241_output.jpg
#  extracting: /content/train/Output/4242_output.jpg
#  extracting: /content/train/Output/4243_output.jpg
#  extracting: /content/train/Output/4244_output.jpg
#  extracting: /content/train/Output/4245_output.jpg
#  extracting: /content/train/Output/4246_output.jpg
#  extracting: /content/train/Output/4247_output.jpg
#  extracting: /content/train/Output/4248_output.jpg
#  extracting: /content/train/Output/4249_output.jpg
#  extracting: /content/train/Output/424_output.jpg
#  extracting: /content/train/Output/4250_output.jpg
#  extracting: /content/train/Output/4251_output.jpg
#  extracting: /content/train/Output/4252_output.jpg
#  extracting: /content/train/Output/4253_output.jpg
#  extracting: /content/train/Output/4254_output.jpg
#  extracting: /content/train/Output/4255_output.jpg
#  extracting: /content/train/Output/4256_output.jpg
#  extracting: /content/train/Output/4257_output.jpg
#  extracting: /content/train/Output/4258_output.jpg
#  extracting: /content/train/Output/4259_output.jpg
#  extracting: /content/train/Output/425_output.jpg
#  extracting: /content/train/Output/4260_output.jpg
#  extracting: /content/train/Output/4261_output.jpg
#  extracting: /content/train/Output/4262_output.jpg
#  extracting: /content/train/Output/4263_output.jpg
#  extracting: /content/train/Output/4264_output.jpg
#  extracting: /content/train/Output/4265_output.jpg
#  extracting: /content/train/Output/4266_output.jpg
#  extracting: /content/train/Output/4267_output.jpg
#  extracting: /content/train/Output/4268_output.jpg
#  extracting: /content/train/Output/4269_output.jpg
#  extracting: /content/train/Output/426_output.jpg
#  extracting: /content/train/Output/4270_output.jpg
#  extracting: /content/train/Output/4271_output.jpg
#  extracting: /content/train/Output/4272_output.jpg
#  extracting: /content/train/Output/4273_output.jpg
#  extracting: /content/train/Output/4274_output.jpg
#  extracting: /content/train/Output/4275_output.jpg
#  extracting: /content/train/Output/4276_output.jpg
#  extracting: /content/train/Output/4277_output.jpg
#  extracting: /content/train/Output/4278_output.jpg
#  extracting: /content/train/Output/4279_output.jpg
#  extracting: /content/train/Output/427_output.jpg
#  extracting: /content/train/Output/4280_output.jpg
#  extracting: /content/train/Output/4281_output.jpg
#  extracting: /content/train/Output/4282_output.jpg
#  extracting: /content/train/Output/4283_output.jpg
#  extracting: /content/train/Output/4284_output.jpg
#  extracting: /content/train/Output/4285_output.jpg
#  extracting: /content/train/Output/4286_output.jpg
#  extracting: /content/train/Output/4287_output.jpg
#  extracting: /content/train/Output/4288_output.jpg
#  extracting: /content/train/Output/4289_output.jpg
#  extracting: /content/train/Output/428_output.jpg
#  extracting: /content/train/Output/4290_output.jpg
#  extracting: /content/train/Output/4291_output.jpg
#  extracting: /content/train/Output/4292_output.jpg
#  extracting: /content/train/Output/4293_output.jpg
#  extracting: /content/train/Output/4294_output.jpg
#  extracting: /content/train/Output/4295_output.jpg
#  extracting: /content/train/Output/4296_output.jpg
#  extracting: /content/train/Output/4297_output.jpg
#  extracting: /content/train/Output/4298_output.jpg
#  extracting: /content/train/Output/4299_output.jpg
#  extracting: /content/train/Output/429_output.jpg
#  extracting: /content/train/Output/42_output.jpg
#  extracting: /content/train/Output/4300_output.jpg
#  extracting: /content/train/Output/4301_output.jpg
#  extracting: /content/train/Output/4302_output.jpg
#  extracting: /content/train/Output/4303_output.jpg
#  extracting: /content/train/Output/4304_output.jpg
#  extracting: /content/train/Output/4305_output.jpg
#  extracting: /content/train/Output/4306_output.jpg
#  extracting: /content/train/Output/4307_output.jpg
#  extracting: /content/train/Output/4308_output.jpg
#  extracting: /content/train/Output/4309_output.jpg
#  extracting: /content/train/Output/430_output.jpg
#  extracting: /content/train/Output/4310_output.jpg
#  extracting: /content/train/Output/4311_output.jpg
#  extracting: /content/train/Output/4312_output.jpg
#  extracting: /content/train/Output/4313_output.jpg
#  extracting: /content/train/Output/4314_output.jpg
#  extracting: /content/train/Output/4315_output.jpg
#  extracting: /content/train/Output/4316_output.jpg
#  extracting: /content/train/Output/4317_output.jpg
#  extracting: /content/train/Output/4318_output.jpg
#  extracting: /content/train/Output/4319_output.jpg
#  extracting: /content/train/Output/431_output.jpg
#  extracting: /content/train/Output/4320_output.jpg
#  extracting: /content/train/Output/4321_output.jpg
#  extracting: /content/train/Output/4322_output.jpg
#  extracting: /content/train/Output/4323_output.jpg
#  extracting: /content/train/Output/4324_output.jpg
#  extracting: /content/train/Output/4325_output.jpg
#  extracting: /content/train/Output/4326_output.jpg
#  extracting: /content/train/Output/4327_output.jpg
#  extracting: /content/train/Output/4328_output.jpg
#  extracting: /content/train/Output/4329_output.jpg
#  extracting: /content/train/Output/432_output.jpg
#  extracting: /content/train/Output/4330_output.jpg
#  extracting: /content/train/Output/4331_output.jpg
#  extracting: /content/train/Output/4332_output.jpg
#  extracting: /content/train/Output/4333_output.jpg
#  extracting: /content/train/Output/4334_output.jpg
#  extracting: /content/train/Output/4335_output.jpg
#  extracting: /content/train/Output/4336_output.jpg
#  extracting: /content/train/Output/4337_output.jpg
#  extracting: /content/train/Output/4338_output.jpg
#  extracting: /content/train/Output/4339_output.jpg
#  extracting: /content/train/Output/433_output.jpg
#  extracting: /content/train/Output/4340_output.jpg
#  extracting: /content/train/Output/4341_output.jpg
#  extracting: /content/train/Output/4342_output.jpg
#  extracting: /content/train/Output/4343_output.jpg
#  extracting: /content/train/Output/4344_output.jpg
#  extracting: /content/train/Output/4345_output.jpg
#  extracting: /content/train/Output/4346_output.jpg
#  extracting: /content/train/Output/4347_output.jpg
#  extracting: /content/train/Output/4348_output.jpg
#  extracting: /content/train/Output/4349_output.jpg
#  extracting: /content/train/Output/434_output.jpg
#  extracting: /content/train/Output/4350_output.jpg
#  extracting: /content/train/Output/4351_output.jpg
#  extracting: /content/train/Output/4352_output.jpg
#  extracting: /content/train/Output/4353_output.jpg
#  extracting: /content/train/Output/4354_output.jpg
#  extracting: /content/train/Output/4355_output.jpg
#  extracting: /content/train/Output/4356_output.jpg
#  extracting: /content/train/Output/4357_output.jpg
#  extracting: /content/train/Output/4358_output.jpg
#  extracting: /content/train/Output/4359_output.jpg
#  extracting: /content/train/Output/435_output.jpg
#  extracting: /content/train/Output/4360_output.jpg
#  extracting: /content/train/Output/4361_output.jpg
#  extracting: /content/train/Output/4362_output.jpg
#  extracting: /content/train/Output/4363_output.jpg
#  extracting: /content/train/Output/4364_output.jpg
#  extracting: /content/train/Output/4365_output.jpg
#  extracting: /content/train/Output/4366_output.jpg
#  extracting: /content/train/Output/4367_output.jpg
#  extracting: /content/train/Output/4368_output.jpg
#  extracting: /content/train/Output/4369_output.jpg
#  extracting: /content/train/Output/436_output.jpg
#  extracting: /content/train/Output/4370_output.jpg
#  extracting: /content/train/Output/4371_output.jpg
#  extracting: /content/train/Output/4372_output.jpg
#  extracting: /content/train/Output/4373_output.jpg
#  extracting: /content/train/Output/4374_output.jpg
#  extracting: /content/train/Output/4375_output.jpg
#  extracting: /content/train/Output/4376_output.jpg
#  extracting: /content/train/Output/4377_output.jpg
#  extracting: /content/train/Output/4378_output.jpg
#  extracting: /content/train/Output/4379_output.jpg
#  extracting: /content/train/Output/437_output.jpg
#  extracting: /content/train/Output/4380_output.jpg
#  extracting: /content/train/Output/4381_output.jpg
#  extracting: /content/train/Output/4382_output.jpg
#  extracting: /content/train/Output/4383_output.jpg
#  extracting: /content/train/Output/4384_output.jpg
#  extracting: /content/train/Output/4385_output.jpg
#  extracting: /content/train/Output/4386_output.jpg
#  extracting: /content/train/Output/4387_output.jpg
#  extracting: /content/train/Output/4388_output.jpg
#  extracting: /content/train/Output/4389_output.jpg
#  extracting: /content/train/Output/438_output.jpg
#  extracting: /content/train/Output/4390_output.jpg
#  extracting: /content/train/Output/4391_output.jpg
#  extracting: /content/train/Output/4392_output.jpg
#  extracting: /content/train/Output/4393_output.jpg
#  extracting: /content/train/Output/4394_output.jpg
#  extracting: /content/train/Output/4395_output.jpg
#  extracting: /content/train/Output/4396_output.jpg
#  extracting: /content/train/Output/4397_output.jpg
#  extracting: /content/train/Output/4398_output.jpg
#  extracting: /content/train/Output/4399_output.jpg
#  extracting: /content/train/Output/439_output.jpg
#  extracting: /content/train/Output/43_output.jpg
#  extracting: /content/train/Output/4400_output.jpg
#  extracting: /content/train/Output/4401_output.jpg
#  extracting: /content/train/Output/4402_output.jpg
#  extracting: /content/train/Output/4403_output.jpg
#  extracting: /content/train/Output/4404_output.jpg
#  extracting: /content/train/Output/4405_output.jpg
#  extracting: /content/train/Output/4406_output.jpg
#  extracting: /content/train/Output/4407_output.jpg
#  extracting: /content/train/Output/4408_output.jpg
#  extracting: /content/train/Output/4409_output.jpg
#  extracting: /content/train/Output/4470_output.jpg
#  extracting: /content/train/Output/4471_output.jpg
#  extracting: /content/train/Output/4472_output.jpg
#  extracting: /content/train/Output/4473_output.jpg
#  extracting: /content/train/Output/4474_output.jpg
#  extracting: /content/train/Output/4475_output.jpg
#  extracting: /content/train/Output/4476_output.jpg
#  extracting: /content/train/Output/4477_output.jpg
#  extracting: /content/train/Output/4478_output.jpg
#  extracting: /content/train/Output/4479_output.jpg
#  extracting: /content/train/Output/447_output.jpg
#  extracting: /content/train/Output/4480_output.jpg
#  extracting: /content/train/Output/4481_output.jpg
#  extracting: /content/train/Output/4482_output.jpg
#  extracting: /content/train/Output/4483_output.jpg
#  extracting: /content/train/Output/4484_output.jpg
#  extracting: /content/train/Output/4485_output.jpg
#  extracting: /content/train/Output/4486_output.jpg
#  extracting: /content/train/Output/4487_output.jpg
#  extracting: /content/train/Output/4488_output.jpg
#  extracting: /content/train/Output/4489_output.jpg
#  extracting: /content/train/Output/448_output.jpg
#  extracting: /content/train/Output/4490_output.jpg
#  extracting: /content/train/Output/4491_output.jpg
#  extracting: /content/train/Output/4492_output.jpg
#  extracting: /content/train/Output/4493_output.jpg
#  extracting: /content/train/Output/4494_output.jpg
#  extracting: /content/train/Output/4495_output.jpg
#  extracting: /content/train/Output/4496_output.jpg
#  extracting: /content/train/Output/4497_output.jpg
#  extracting: /content/train/Output/4498_output.jpg
#  extracting: /content/train/Output/4499_output.jpg
#  extracting: /content/train/Output/449_output.jpg
#  extracting: /content/train/Output/44_output.jpg
#  extracting: /content/train/Output/4500_output.jpg
#  extracting: /content/train/Output/4501_output.jpg
#  extracting: /content/train/Output/4502_output.jpg
#  extracting: /content/train/Output/4503_output.jpg
#  extracting: /content/train/Output/4504_output.jpg
#  extracting: /content/train/Output/4505_output.jpg
#  extracting: /content/train/Output/4506_output.jpg
#  extracting: /content/train/Output/4507_output.jpg
#  extracting: /content/train/Output/4508_output.jpg
#  extracting: /content/train/Output/4509_output.jpg
#  extracting: /content/train/Output/450_output.jpg
#  extracting: /content/train/Output/4510_output.jpg
#  extracting: /content/train/Output/4511_output.jpg
#  extracting: /content/train/Output/4512_output.jpg
#  extracting: /content/train/Output/4513_output.jpg
#  extracting: /content/train/Output/4514_output.jpg
#  extracting: /content/train/Output/4515_output.jpg
#  extracting: /content/train/Output/4516_output.jpg
#  extracting: /content/train/Output/4517_output.jpg
#  extracting: /content/train/Output/4518_output.jpg
#  extracting: /content/train/Output/4519_output.jpg
#  extracting: /content/train/Output/451_output.jpg
#  extracting: /content/train/Output/4520_output.jpg
#  extracting: /content/train/Output/4521_output.jpg
#  extracting: /content/train/Output/4522_output.jpg
#  extracting: /content/train/Output/4523_output.jpg
#  extracting: /content/train/Output/4524_output.jpg
#  extracting: /content/train/Output/4525_output.jpg
#  extracting: /content/train/Output/4526_output.jpg
#  extracting: /content/train/Output/4527_output.jpg
#  extracting: /content/train/Output/4528_output.jpg
#  extracting: /content/train/Output/4529_output.jpg
#  extracting: /content/train/Output/452_output.jpg
#  extracting: /content/train/Output/4530_output.jpg
#  extracting: /content/train/Output/4531_output.jpg
#  extracting: /content/train/Output/4532_output.jpg
#  extracting: /content/train/Output/4533_output.jpg
#  extracting: /content/train/Output/4534_output.jpg
#  extracting: /content/train/Output/4535_output.jpg
#  extracting: /content/train/Output/4536_output.jpg
#  extracting: /content/train/Output/4537_output.jpg
#  extracting: /content/train/Output/4538_output.jpg
#  extracting: /content/train/Output/4539_output.jpg
#  extracting: /content/train/Output/453_output.jpg
#  extracting: /content/train/Output/4540_output.jpg
#  extracting: /content/train/Output/4541_output.jpg
#  extracting: /content/train/Output/4542_output.jpg
#  extracting: /content/train/Output/4543_output.jpg
#  extracting: /content/train/Output/4544_output.jpg
#  extracting: /content/train/Output/4545_output.jpg
#  extracting: /content/train/Output/4546_output.jpg
#  extracting: /content/train/Output/4547_output.jpg
#  extracting: /content/train/Output/4548_output.jpg
#  extracting: /content/train/Output/4549_output.jpg
#  extracting: /content/train/Output/454_output.jpg
#  extracting: /content/train/Output/4550_output.jpg
#  extracting: /content/train/Output/4551_output.jpg
#  extracting: /content/train/Output/4552_output.jpg
#  extracting: /content/train/Output/4553_output.jpg
#  extracting: /content/train/Output/4554_output.jpg
#  extracting: /content/train/Output/4555_output.jpg
#  extracting: /content/train/Output/4556_output.jpg
#  extracting: /content/train/Output/4557_output.jpg
#  extracting: /content/train/Output/4558_output.jpg
#  extracting: /content/train/Output/4559_output.jpg
#  extracting: /content/train/Output/455_output.jpg
#  extracting: /content/train/Output/4560_output.jpg
#  extracting: /content/train/Output/4561_output.jpg
#  extracting: /content/train/Output/4562_output.jpg
#  extracting: /content/train/Output/4563_output.jpg
#  extracting: /content/train/Output/4564_output.jpg
#  extracting: /content/train/Output/4565_output.jpg
#  extracting: /content/train/Output/4566_output.jpg
#  extracting: /content/train/Output/4567_output.jpg
#  extracting: /content/train/Output/4568_output.jpg
#  extracting: /content/train/Output/4569_output.jpg
#  extracting: /content/train/Output/456_output.jpg
#  extracting: /content/train/Output/4570_output.jpg
#  extracting: /content/train/Output/4571_output.jpg
#  extracting: /content/train/Output/4572_output.jpg
#  extracting: /content/train/Output/4573_output.jpg
#  extracting: /content/train/Output/4574_output.jpg
#  extracting: /content/train/Output/4575_output.jpg
#  extracting: /content/train/Output/4576_output.jpg
#  extracting: /content/train/Output/4577_output.jpg
#  extracting: /content/train/Output/4578_output.jpg
#  extracting: /content/train/Output/4579_output.jpg
#  extracting: /content/train/Output/457_output.jpg
#  extracting: /content/train/Output/4580_output.jpg
#  extracting: /content/train/Output/4581_output.jpg
#  extracting: /content/train/Output/4582_output.jpg
#  extracting: /content/train/Output/4583_output.jpg
#  extracting: /content/train/Output/4584_output.jpg
#  extracting: /content/train/Output/4585_output.jpg
#  extracting: /content/train/Output/4586_output.jpg
#  extracting: /content/train/Output/4587_output.jpg
#  extracting: /content/train/Output/4588_output.jpg
#  extracting: /content/train/Output/4589_output.jpg
#  extracting: /content/train/Output/458_output.jpg
#  extracting: /content/train/Output/4590_output.jpg
#  extracting: /content/train/Output/4591_output.jpg
#  extracting: /content/train/Output/4592_output.jpg
#  extracting: /content/train/Output/4593_output.jpg
#  extracting: /content/train/Output/4594_output.jpg
#  extracting: /content/train/Output/4595_output.jpg
#  extracting: /content/train/Output/4596_output.jpg
#  extracting: /content/train/Output/4597_output.jpg
#  extracting: /content/train/Output/4598_output.jpg
#  extracting: /content/train/Output/4599_output.jpg
#  extracting: /content/train/Output/459_output.jpg
#  extracting: /content/train/Output/45_output.jpg
#  extracting: /content/train/Output/4600_output.jpg
#  extracting: /content/train/Output/4601_output.jpg
#  extracting: /content/train/Output/4602_output.jpg
#  extracting: /content/train/Output/4603_output.jpg
#  extracting: /content/train/Output/4604_output.jpg
#  extracting: /content/train/Output/4605_output.jpg
#  extracting: /content/train/Output/4606_output.jpg
#  extracting: /content/train/Output/4607_output.jpg
#  extracting: /content/train/Output/4608_output.jpg
#  extracting: /content/train/Output/4609_output.jpg
#  extracting: /content/train/Output/460_output.jpg
#  extracting: /content/train/Output/4610_output.jpg
#  extracting: /content/train/Output/4611_output.jpg
#  extracting: /content/train/Output/4612_output.jpg
#  extracting: /content/train/Output/4613_output.jpg
#  extracting: /content/train/Output/4614_output.jpg
#  extracting: /content/train/Output/4615_output.jpg
#  extracting: /content/train/Output/4616_output.jpg
#  extracting: /content/train/Output/4617_output.jpg
#  extracting: /content/train/Output/4618_output.jpg
#  extracting: /content/train/Output/4619_output.jpg
#  extracting: /content/train/Output/461_output.jpg
#  extracting: /content/train/Output/4620_output.jpg
#  extracting: /content/train/Output/4621_output.jpg
#  extracting: /content/train/Output/4622_output.jpg
#  extracting: /content/train/Output/4623_output.jpg
#  extracting: /content/train/Output/4624_output.jpg
#  extracting: /content/train/Output/4625_output.jpg
#  extracting: /content/train/Output/4626_output.jpg
#  extracting: /content/train/Output/4627_output.jpg
#  extracting: /content/train/Output/4628_output.jpg
#  extracting: /content/train/Output/4629_output.jpg
#  extracting: /content/train/Output/462_output.jpg
#  extracting: /content/train/Output/4630_output.jpg
#  extracting: /content/train/Output/4631_output.jpg
#  extracting: /content/train/Output/4632_output.jpg
#  extracting: /content/train/Output/4633_output.jpg
#  extracting: /content/train/Output/4634_output.jpg
#  extracting: /content/train/Output/4635_output.jpg
#  extracting: /content/train/Output/4636_output.jpg
#  extracting: /content/train/Output/4637_output.jpg
#  extracting: /content/train/Output/4638_output.jpg
#  extracting: /content/train/Output/4639_output.jpg
#  extracting: /content/train/Output/463_output.jpg
#  extracting: /content/train/Output/4640_output.jpg
#  extracting: /content/train/Output/4641_output.jpg
#  extracting: /content/train/Output/4642_output.jpg
#  extracting: /content/train/Output/4643_output.jpg
#  extracting: /content/train/Output/4644_output.jpg
#  extracting: /content/train/Output/4645_output.jpg
#  extracting: /content/train/Output/4646_output.jpg
#  extracting: /content/train/Output/4647_output.jpg
#  extracting: /content/train/Output/4648_output.jpg
#  extracting: /content/train/Output/4649_output.jpg
#  extracting: /content/train/Output/464_output.jpg
#  extracting: /content/train/Output/4650_output.jpg
#  extracting: /content/train/Output/4651_output.jpg
#  extracting: /content/train/Output/4652_output.jpg
#  extracting: /content/train/Output/4653_output.jpg
#  extracting: /content/train/Output/4654_output.jpg
#  extracting: /content/train/Output/4655_output.jpg
#  extracting: /content/train/Output/4656_output.jpg
#  extracting: /content/train/Output/4657_output.jpg
#  extracting: /content/train/Output/4658_output.jpg
#  extracting: /content/train/Output/4659_output.jpg
#  extracting: /content/train/Output/465_output.jpg
#  extracting: /content/train/Output/4660_output.jpg
#  extracting: /content/train/Output/4661_output.jpg
#  extracting: /content/train/Output/4662_output.jpg
#  extracting: /content/train/Output/4663_output.jpg
#  extracting: /content/train/Output/4664_output.jpg
#  extracting: /content/train/Output/4665_output.jpg
#  extracting: /content/train/Output/4666_output.jpg
#  extracting: /content/train/Output/4667_output.jpg
#  extracting: /content/train/Output/4668_output.jpg
#  extracting: /content/train/Output/4669_output.jpg
#  extracting: /content/train/Output/466_output.jpg
#  extracting: /content/train/Output/4670_output.jpg
#  extracting: /content/train/Output/4671_output.jpg
#  extracting: /content/train/Output/4672_output.jpg
#  extracting: /content/train/Output/4673_output.jpg
#  extracting: /content/train/Output/4674_output.jpg
#  extracting: /content/train/Output/4675_output.jpg
#  extracting: /content/train/Output/4676_output.jpg
#  extracting: /content/train/Output/4677_output.jpg
#  extracting: /content/train/Output/4678_output.jpg
#  extracting: /content/train/Output/4679_output.jpg
#  extracting: /content/train/Output/467_output.jpg
#  extracting: /content/train/Output/4680_output.jpg
#  extracting: /content/train/Output/4681_output.jpg
#  extracting: /content/train/Output/4682_output.jpg
#  extracting: /content/train/Output/4683_output.jpg
#  extracting: /content/train/Output/4684_output.jpg
#  extracting: /content/train/Output/4685_output.jpg
#  extracting: /content/train/Output/4686_output.jpg
#  extracting: /content/train/Output/4687_output.jpg
#  extracting: /content/train/Output/4688_output.jpg
#  extracting: /content/train/Output/4689_output.jpg
#  extracting: /content/train/Output/468_output.jpg
# ...
#  extracting: /content/train/Output/809_output.jpg
#  extracting: /content/train/Output/80_output.jpg
#  extracting: /content/train/Output/8100_output.jpg
#  extracting: /content/train/Output/8101_output.jpg
#  extracting: /content/train/Output/8102_output.jpg
#  extracting: /content/train/Output/8103_output.jpg
#  extracting: /content/train/Output/8104_output.jpg
#  extracting: /content/train/Output/8105_output.jpg
#  extracting: /content/train/Output/8106_output.jpg
#  extracting: /content/train/Output/8107_output.jpg
#  extracting: /content/train/Output/8108_output.jpg
#  extracting: /content/train/Output/8109_output.jpg
#  extracting: /content/train/Output/810_output.jpg
#  extracting: /content/train/Output/8110_output.jpg
#  extracting: /content/train/Output/8111_output.jpg
#  extracting: /content/train/Output/8112_output.jpg
#  extracting: /content/train/Output/8113_output.jpg
#  extracting: /content/train/Output/8114_output.jpg
#  extracting: /content/train/Output/8115_output.jpg
#  extracting: /content/train/Output/8116_output.jpg
#  extracting: /content/train/Output/8117_output.jpg
#  extracting: /content/train/Output/8118_output.jpg
#  extracting: /content/train/Output/992_output.jpg
#  extracting: /content/train/Output/993_output.jpg
#  extracting: /content/train/Output/994_output.jpg
#  extracting: /content/train/Output/995_output.jpg
#  extracting: /content/train/Output/996_output.jpg
#  extracting: /content/train/Output/997_output.jpg
#  extracting: /content/train/Output/998_output.jpg
#  extracting: /content/train/Output/999_output.jpg
#  extracting: /content/train/Output/99_output.jpg
#  extracting: /content/train/Output/9_output.jpg
#  extracting: /content/train/train.csv

# %%
import os
from glob import glob
from pathlib import Path

import matplotlib.pyplot as plt
import pytorch_lightning as pl
import torch
from PIL import Image
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision.transforms.functional import center_crop
from torchvision.utils import make_grid, save_image
from tqdm.auto import tqdm

import torch.nn.functional as F
from torch.nn import Module, Conv2d
from torch.nn.utils import spectral_norm
from torch.nn.functional import interpolate, relu

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-92f73ec45748> in <module>
#       4
#       5 import matplotlib.pyplot as plt
# ----> 6 import pytorch_lightning as pl
#       7 import torch
#       8 from PIL import Image
#
# ModuleNotFoundError: No module named 'pytorch_lightning'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
config_defaults = {
    'BATCH_SIZE' : 8,
    'IN_CHANNEL' : 7,
    'OUT_CHANNEL' : 3,
    'LOAD_CHECKPOINT' : False,
    'PATH_CONTEXT' : '/content/train/',
    'PATH_DATA' : '/content/drive/MyDrive/grass/datasets/train.zip',
    'PATH_CHECKPOINT' : '/content/drive/MyDrive/grass/experiments/example-sea-creature-noise/lightning_logs/version_13/checkpoints/epoch=8-step=4500.ckpt',
    'Lr_gen' : 0.0002,
    'Lr_disc' : 0.0002,
    'MAX_EPOCH' : 10,
    'SAVE_NTH_BATCH' : 20,
    'DATASET_SIZE' : 2000,
    'LAMBDA_RECON' : 80,
    'HALF_SIZE_LOSS_WEIGHT' : 1,
    'DISPLAY_LOSS_N': 40,
    'TRAIN_DISCRIMINATOR': 2,
    'RESULT_PATH': '/content/drive/MyDrive/grass/experiments/example-sea-creature-TinySPADE/',
    'INPUT_DIM': 50*30*128,
    'INITIAL_FILTER_SIZE': 128,
    }

CONFIG = config_defaults

# %%
class GrassDataset(Dataset):
  def __init__(self, path, num_items = -1):
    self.df = pd.read_csv(path + "train.csv")
    self.path = path
    self.length = num_items
    if num_items == -1:
      self.length = len(self.df)
    else:
      self.length = min(len(self.df),num_items)
      self.df = self.df.sample(n = self.length, replace=False)
    self.df = self.df.reset_index(drop=True)
    self.df.head()

  def __len__(self):
    return self.length

  def __getitem__(self, idx):
    inputImagePath = self.path + self.df['Input'][idx][2:]
       
    inputImage = Image.open(inputImagePath)
    inputImage = transforms.functional.to_tensor(inputImage)

   
    depthImagePath = self.path + self.df['Depth'][idx][2:]
    depthImage = Image.open(depthImagePath)
    depthImage = transforms.functional.to_tensor(depthImage)

    nImagePath = self.path + self.df['Normal'][idx][2:]
    nImage = Image.open(nImagePath)
    nImage = transforms.functional.to_tensor(nImage)

    realImagePath = self.path + self.df['Output'][idx][2:]
    realImage = Image.open(realImagePath)
    real = transforms.functional.to_tensor(realImage)
   
    #                                       here
    condition = torch.cat((inputImage, depthImage[0:1, :, :], nImage), 0) # (3+1+3 = 7) x 480 x 800

    return idx, real, condition

class RAMGrassDataset(Dataset): 
#This one loads the dataset onto the RAM, to speed up training speed, especially if you're running a large number of epochs
#Be very careful about how many items you want there to be here
  def __init__(self, path, num_items = -1):
    print("preparing RAM dataset, hopefully this doesn't take very long")
    self.df = pd.read_csv(path + "train.csv")
    self.path = path
    self.length = num_items
    if num_items == -1:
      self.length = len(self.df)
    else:
      self.length = min(len(self.df),num_items)
      self.df = self.df.sample(n = self.length, replace=False)
    self.df = self.df.reset_index(drop=True)


    self.real = []
    self.condition = []
    print("prepared all variables, adding data to RAM")
    for i in range(self.length):
      idx, real, condition = self.getitem(i)
      self.real.append(real)
      self.condition.append(condition)
    print("dataset added to RAM")

  def __len__(self):
    return self.length

  def __getitem__(self, idx):
    return self.real[idx], self.condition[idx]

  def getitem(self, idx):
    inputImagePath = self.path + self.df['Input'][idx][2:]
       
    inputImage = Image.open(inputImagePath)
    inputImage = transforms.functional.to_tensor(inputImage)

    print(inputImage)
    depthImagePath = self.path + self.df['Depth'][idx][2:]
    depthImage = Image.open(depthImagePath)
    depthImage = transforms.functional.to_tensor(depthImage)

    nImagePath = self.path + self.df['Normal'][idx][2:]
    nImage = Image.open(nImagePath)
    nImage = transforms.functional.to_tensor(nImage)


    realImagePath = self.path + self.df['Output'][idx][2:]
    realImage = Image.open(realImagePath)
    real = transforms.functional.to_tensor(realImage)

    #                                       here
    condition = torch.cat((inputImage, depthImage[0:1, :, :], nImage), 0) # (3+1+3 = 7) x 480 x 800

    return idx, real, condition

# %%
#load dataset
dataset = GrassDataset(CONFIG['PATH_CONTEXT'], CONFIG['DATASET_SIZE'])
dataloader = DataLoader(dataset, batch_size=CONFIG['BATCH_SIZE'], shuffle=True)

# %%
class DownSampleConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel=4, strides=2, padding=1, activation=True, batchnorm=True):

        super().__init__()
        self.activation = activation
        self.batchnorm = batchnorm

        self.conv = nn.Conv2d(in_channels, out_channels, kernel, strides, padding)

        if batchnorm:
            self.bn = nn.BatchNorm2d(out_channels)
            #self.bn = nn.GroupNorm(1, out_channels)

        if activation:
            self.act = nn.LeakyReLU(0.2)

    def forward(self, x):
        x = self.conv(x)
        if self.batchnorm:
            x = self.bn(x)
        if self.activation:
            x = self.act(x)
        return x

class UpSampleConv(nn.Module):

    def __init__(
        self,
        in_channels,
        out_channels,
        kernel=4,
        strides=2,
        padding=1,
        activation=True,
        batchnorm=True,
        dropout=False
    ):
        super().__init__()
        self.activation = activation
        self.batchnorm = batchnorm
        self.dropout = dropout

        self.deconv = nn.ConvTranspose2d(in_channels, out_channels, kernel, strides, padding)

        if batchnorm:
            self.bn = nn.BatchNorm2d(out_channels)

        if activation:
            self.act = nn.ReLU(True)

        if dropout:
            self.drop = nn.Dropout2d(0.5)

    def forward(self, x):
        x = self.deconv(x)
        if self.batchnorm:
            x = self.bn(x)

        if self.dropout:
            x = self.drop(x)
        return x

# %%
# class ResnetBlock(nn.Module):
#     def __init__(self, dim, padding_type, norm_layer=nn.BatchNorm2d, activation=nn.ReLU(True), use_dropout=False):
#         super(ResnetBlock, self).__init__()
#         self.build_conv_block(dim, padding_type, norm_layer, activation, use_dropout)

#     def build_conv_block(self, dim, padding_type, norm_layer, activation, use_dropout):
#         self.activation = activation;
#         self.norm_layer = norm_layer;
#         self.dropout = use_dropout;

#         if(norm_layer):
#             self.nl = nn.BatchNorm2d(dim)
#             self.nl2 = nn.BatchNorm2d(dim)

          
#         if activation:
#             self.act = nn.ReLU(True)
#             self.act2 = nn.ReLU(True)
          
#         if use_dropout:
#             self.dp = nn.Dropout(0.5)

#         self.conv_1 = nn.Conv2d(dim, dim, kernel_size=3, padding=1)


#         self.conv_2 = nn.Conv2d(dim, dim, kernel_size=3, padding=1)


#     def forward(self, x):
        
#         y = self.conv_1(x)
#         y = self.nl(y)
#         y = self.act(y)

#         #y = self.dp(y) Regularisation

#         y = self.conv_2(y)
#         y = self.nl2(y)
#         y = self.act2(y)

#         return x + y

# %%
# class RobGenerator(nn.Module):
#     def __init__(self, in_channels, out_channels):
#         super().__init__()
       
#         self.layers = [
#             DownSampleConv(in_channels, 64, batchnorm=False),  # bs x 64 x 240 x 400
#             DownSampleConv(64, 128),  # bs x 128 x 120 x 200
#             ResnetBlock(128, padding_type = 'reflect', use_dropout=True), # bs x 128 x 120 x 200
#             ResnetBlock(128, padding_type = 'reflect', use_dropout=True), # bs x 128 x 120 x 200
#             ResnetBlock(128, padding_type = 'reflect', use_dropout=True), # bs x 128 x 120 x 200
#             UpSampleConv(128, 128),  # bs x 128 x 240 x 400
#             ResnetBlock(128, padding_type = 'reflect', use_dropout=True), # bs x 128 x 240 x 400
#             ResnetBlock(128, padding_type = 'reflect', use_dropout=True), # bs x 128 x 240 x 400
#             nn.ConvTranspose2d(128, out_channels, kernel_size=4, stride=2, padding=1), # bs x 3 x 480 x 800
#         ]

#         self.tanh = nn.Tanh()
#         self.layers = nn.ModuleList(self.layers)

#     def forward(self, x):
#         for layer in self.layers:
#             x = layer(x)
#         return self.tanh(x)

# %%
class SPADE(Module):
    def __init__(self, k):
        super().__init__()
        num_filters = 64
        kernel_size = 3
        # self.conv = spectral_norm(Conv2d(CONFIG["IN_CHANNEL"], num_filters, kernel_size=(kernel_size, kernel_size), padding=1)) #made changes on inputChannel
        self.conv_gamma = Conv2d(k, k, kernel_size=(kernel_size, kernel_size), padding=1)
        self.conv_beta = Conv2d(k, k, kernel_size=(kernel_size, kernel_size), padding=1)
        self.activation = nn.Sequential(
            nn.Conv2d(CONFIG['IN_CHANNEL'], k, kernel_size=(kernel_size, kernel_size), padding =1),
            nn.ReLU()
        )
        self.normalization = nn.BatchNorm2d(k)
        self.conv = nn.Conv2d(CONFIG["IN_CHANNEL"], k, kernel_size=(kernel_size, kernel_size), padding=1,)

    def forward(self, x, seg):
        #x = (b, 128, h, w), seg = (b, 4, h,w )
        # print('In SPADE')
        normalized = self.normalization(x) #b, 128, h, w

        seg = self.activation(seg)  #b, k, h, w

        seg_gamma = self.conv_gamma(seg)
        # print(f'seg_gamma: {seg_gamma.shape}')

        seg_beta = self.conv_beta(seg) #b, k, h, w
        # print(f'seg_beta: {seg_beta.shape}')

        x = normalized*(1+seg_gamma) + seg_beta #b, k, h, w
        # print(f'exit: {x.shape}')
        return x

class SPADEResBlk(Module):
    def __init__(self, k, skip=False):
        super().__init__()
        kernel_size = 3
        self.skip = skip
        
        if self.skip:
            self.spade1 = SPADE(2*k)
            self.conv1 = Conv2d(2*k, k, kernel_size=(kernel_size, kernel_size), padding=1, bias=False)
            # self.spade_skip = SPADE(2*k)
            self.conv_skip = Conv2d(2*k, k, kernel_size=(kernel_size, kernel_size), padding=1, bias=False)
        else:
            self.spade1 = SPADE(k)
            self.conv1 = Conv2d(k, k, kernel_size=(kernel_size, kernel_size), padding=1, bias=False)
    
    def forward(self, x, seg):
        # print(f'In SpadeResBlk')
        x_skip = x #x=b*channel(-1)*h*w
        # print(f'before spade1: x {x.shape} seg: {seg.shape} ')
        x = relu(self.spade1(x, seg)) #b, 128, 30, 50
        # print(f'After spade1: {x.shape}')
        x = self.conv1(x) #b, 128, 30, 50

        if self.skip:
            # x_skip = relu(self.spade_skip(x_skip, seg))
            x_skip = self.conv_skip(x_skip) #b, c/2, h, w
        # print(f'After spade1: {(x_skip + x).shape}')
        return x_skip + x 

class SPADEGenerator(nn.Module):
    def __init__(self, inchannels, outchannels): #---------_Remember inchannels
        super().__init__()
        kernel_size = 3
        # self.ln = nn.Linear(CONFIG['INITIAL_FILTER_SIZE'], CONFIG['INPUT_DIM'])

        self.spade_resblk1 = SPADEResBlk(128)
        self.spade_resblk2 = SPADEResBlk(128)
        self.spade_resblk3 = SPADEResBlk(64, skip=True)
        self.spade_resblk4 = SPADEResBlk(32, skip=True)
        self.conv = nn.utils.spectral_norm(nn.Conv2d(32, outchannels, kernel_size=(3,3), padding=1))
        self.convTrans128 = nn.ConvTranspose2d(128, 128, kernel_size = 2, stride = 2)
        self.convTrans64 = nn.ConvTranspose2d(64, 64, kernel_size = 2, stride = 2)
        self.convTrans32 = nn.ConvTranspose2d(32, 32, kernel_size = 2, stride = 2)
        self.noise = torch.normal(0, 1, (8,7,30,50)).to(device)
        self.convInit = Conv2d(CONFIG['IN_CHANNEL'], 128, kernel_size=(kernel_size, kernel_size), padding=1, bias=False) 


    
    def forward(self, seg):
  
        # x = self.ln(self.noise)
        # x = x.view(CONFIG['BATCH_SIZE'], -1, 30, 50) #b*128*30*50 change 4 4 such that -1 = 128 If change this also change hidden layer size with x*y
        #print(f'After view {x.shape}')
        #x.shape = 8,4,15,25
        m4 = F.interpolate(seg, scale_factor = 0.5, mode = "bicubic") #b, 4, 240, 400
        m3 = F.interpolate(m4, scale_factor = 0.5, mode = "bicubic") #b, 4, 120, 200
        m2 = F.interpolate(m3, scale_factor = 0.5, mode = "bicubic") #b, 4, 60, 100
        m1 = F.interpolate(m2, scale_factor = 0.5, mode = "bicubic") #b, 4, 30, 50 

        # print(f'm1: {m1.shape}')
        
        x = self.convInit(self.noise)

        x = self.spade_resblk1(x, m1) #b, 128, 30, 50
        x= self.convTrans128(x) #b, 128, 60, 100
    
        x = self.spade_resblk2(x, m2) #b, 128, 60, 100
        x = self.convTrans128(x) #b, 128, 120, 200

        x = self.spade_resblk3(x, m3)  #b, 64, 120,200
        #print(f'resblk3: {x.shape}')
        x= self.convTrans64(x) 

       # print(f'interpolate3: {x.shape}')
        
        x = self.spade_resblk4(x, m4)  #b, 32, 240, 400
        # print(f'resblk4: {x.shape}')
        x= self.convTrans32(x) #b,32,480,800

        x = F.tanh(self.conv(x)) #b, 3, 480, 800
        # print(f'tanh: {x.shape}')
        return x

# %%
class PatchGAN(nn.Module):
    def __init__(self, input_channels):
        super().__init__()
        self.d1 = DownSampleConv(input_channels, 32, batchnorm=False)
        self.d2 = DownSampleConv(32, 64)
        self.d3 = DownSampleConv(64, 64)
        self.d4 = DownSampleConv(64, 64)
        self.final = nn.Conv2d(64, 1, kernel_size=1)

    def forward(self, x, y):
        x = torch.cat([x, y], axis=1)
        x0 = self.d1(x)
        x1 = self.d2(x0)
        x2 = self.d3(x1)
        x3 = self.d4(x2)
        xn = self.final(x3)
        return xn

class MultilevelPatchGAN(nn.Module):
    def __init__(self, input_channels):
        super().__init__()
        self.d1 = DownSampleConv(input_channels, 32, batchnorm=False)
        self.d2 = DownSampleConv(32, 64)
        self.d3 = DownSampleConv(64, 64)
        self.d4 = DownSampleConv(64, 64)
        self.final = nn.Conv2d(64, 1, kernel_size=1)

        self.dd1 = DownSampleConv(input_channels, 32, batchnorm=False)
        self.dd2 = DownSampleConv(32, 64)
        self.dd3 = DownSampleConv(64, 64)
        self.dfinal = nn.Conv2d(64, 1, kernel_size=1)

    def forward(self, x, y):
        x = torch.cat([x, y], axis=1)
        xx = torch.nn.functional.interpolate(x, scale_factor=0.5, mode="bicubic")

        x0 = self.d1(x)
        x1 = self.d2(x0)
        x2 = self.d3(x1)
        x3 = self.d4(x2)
        xn = self.final(x3)

        xx0 = self.dd1(xx)
        xx1 = self.dd2(xx0)
        xx2 = self.dd3(xx1)
        xxn = self.dfinal(xx2)
        return xn, xxn

# %%
def _weights_init(m):
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
    if isinstance(m, nn.BatchNorm2d):
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
        torch.nn.init.constant_(m.bias, 0)
        
def display_progress(cond, fake, real, figsize=(10,5)):
    cond = cond.detach().cpu().permute(1, 2, 0)
    fake = fake.detach().cpu().permute(1, 2, 0)
    real = real.detach().cpu().permute(1, 2, 0)
    
    fig, ax = plt.subplots(1, 3, figsize=figsize)
    #print(cond.shape)
    ax[0].imshow(cond[:,:,0:3])
    ax[2].imshow(fake)
    ax[1].imshow(real)
    plt.show()

def draw_result(lst_itrd, lst_itrg, lst_fake, lst_real,lst_recon,lst_adver):
  # print(f'{label1} {len(lst_err1)}')
  # print(f'{label2} {len(lst_err2)}')

  fig, axs = plt.subplots(2)
  fig.suptitle('loss')
  
  axs[0].plot(lst_itrd, lst_fake, '-b', label = 'Fake loss')
  axs[0].legend()
  axs[0].plot(lst_itrd, lst_real, '-k', label = 'Real loss')
  axs[0].legend()
  axs[1].plot(lst_itrg, lst_adver, '-r', label = 'Adversarial loss')
  axs[1].plot(lst_itrg, lst_recon, '-g', label = 'Reconstruction loss')



  plt.ylabel('loss')
  plt.xlabel('iteration')
  plt.legend()
  plt.show()
  # print(f'fake: {lst_fake[-1]} real: {lst_real[-1]} recon: {lst_recon[-1]} adver: {lst_adver[-1]}')

# %%
class GAN(pl.LightningModule):

    def __init__(self, in_channels, out_channels, learning_rate=0.0002, next_save_idx = 0):

        super().__init__()
        self.save_hyperparameters()

        self.gen = SPADEGenerator(in_channels, out_channels)
        self.patch_gan = PatchGAN(in_channels + out_channels)
        # intializing weights
        self.gen = self.gen.apply(_weights_init)

        self.patch_gan = self.patch_gan.apply(_weights_init)

        self.adversarial_criterion = nn.BCEWithLogitsLoss()
        self.recon_criterion = nn.L1Loss()
        self.trainidx = next_save_idx

        self.lambda_recon = CONFIG["LAMBDA_RECON"]

        self.recon_lossl = []
        self.adverserial_lossl = []
        self.itrg = []
        self.itrd = []
        self.real_lossl = []
        self.fake_lossl = []

    def _gen_step(self, real_images, conditioned_images):
        fake_images = self.gen(conditioned_images)
        disc_logits = self.patch_gan(fake_images, conditioned_images)
        adversarial_loss = self.adversarial_criterion(disc_logits, torch.ones_like(disc_logits))

        recon_loss = self.recon_criterion(fake_images, real_images)
        self.adverserial_lossl.append(adversarial_loss.cpu().data.numpy())
        self.recon_lossl.append(recon_loss.cpu().data.numpy())
        self.itrg.append(len(self.adverserial_lossl))
        return adversarial_loss + self.lambda_recon * recon_loss
        
    def _disc_step(self, real_images, conditioned_images):
        fake_images = self.gen(conditioned_images).detach()

        fake_logits = self.patch_gan(fake_images, conditioned_images)
        real_logits = self.patch_gan(real_images, conditioned_images)

        fake_loss = self.adversarial_criterion(fake_logits, torch.zeros_like(fake_logits))
        real_loss = self.adversarial_criterion(real_logits, torch.ones_like(real_logits))
        self.fake_lossl.append(fake_loss.cpu().data.numpy())
        self.real_lossl.append(real_loss.cpu().data.numpy())
        self.itrd.append(len(self.fake_lossl))
        return (real_loss + fake_loss) / 2

    def configure_optimizers(self):
        gen_opt = torch.optim.Adam(self.gen.parameters(), lr=CONFIG['Lr_gen'])
        disc_opt = torch.optim.Adam(self.patch_gan.parameters(), lr=CONFIG['Lr_disc'])
        return disc_opt, gen_opt

    def training_step(self, batch, batch_idx, optimizer_idx):
        idx, real, condition = batch

        loss = None

        if optimizer_idx == 1:
            loss = self._gen_step(real, condition)

            self.log('Generator Loss', loss)
        
        elif(batch_idx%CONFIG['TRAIN_DISCRIMINATOR']==0 and optimizer_idx ==0 ):
            loss = self._disc_step(real, condition)

            self.log('PatchGAN Loss', loss)
        

        if batch_idx% CONFIG['SAVE_NTH_BATCH']==0and optimizer_idx==1:
            print(f'batch size {batch_idx}')
            fake = self.gen(condition).detach()
            display_progress(condition[0], fake[0], real[0])
            for i in range(1):
              index = int(idx[i])+1
              path = CONFIG['RESULT_PATH'] + str(self.trainidx) + "_" + str(index) + ".png"
              self.trainidx+=1
              save_image(fake[i], path)
              # draw_result(self.itrd, self.fake_lossl, self.real_lossl, label1 = 'Fake Loss', label2 = 'Real Loss') 
              # draw_result(self.itrg, self.recon_lossl, self.adverserial_lossl, label1 = 'Recon Loss', label2 = 'Adverserial Loss') 

              # print(f'batch: {batch_idx}/{ CONFIG['DATASET_SIZE']/CONFIG['BATCH_SIZE']}')

        if batch_idx%CONFIG['DISPLAY_LOSS_N'] ==0 and batch_idx != 0:
          draw_result(self.itrd, self.itrg, self.fake_lossl, self.real_lossl, self.recon_lossl, self.adverserial_lossl) 

        return loss

    def forward(self, x, y, z):
        x = torch.concat((x,y,z), axis=1)
        return self.gen(x)

# %%
#load dataset
dataset = GrassDataset(CONFIG['PATH_CONTEXT'], CONFIG['DATASET_SIZE'])
dataloader = DataLoader(dataset, batch_size=CONFIG['BATCH_SIZE'], shuffle=True)

# %%
xadversarial_loss = nn.BCEWithLogitsLoss()
reconstruction_loss = nn.L1Loss()

if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

if CONFIG['LOAD_CHECKPOINT']:
  model = GAN.load_from_checkpoint(CONFIG['PATH_CHECKPOINT'])
else:
  model = GAN(CONFIG['IN_CHANNEL'], CONFIG['OUT_CHANNEL'])

trainer = pl.Trainer(max_epochs=CONFIG['MAX_EPOCH'], gpus=1, default_root_dir = CONFIG['RESULT_PATH'])
trainer.fit(model, dataloader)

# %% [markdown]
# 1. Used linear layers
# 2. Decreased Filter size to 128->64
# 3. lr = 0.0002
# 4. Used lekayReLU
# 5. Decreased Recon factor 100->50

# %% [markdown]
# ## After training:
# 1. the losses remain same after nth epoch
# 2. Recon loss : ~0.1
# 3. Real loss: ~0.67
# 4. fake loss: ~0.71
# 5. Adverserial: ~0.7

# %%
import torch
torch.cuda.empty_cache()

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# import torch
# from PIL import Image
# from torchvision.transforms import transforms

# image = Image.open("/content/train/Input/0_input.jpg")
# image.show()
# T = transforms.ToTensor()
# reI = T(image)
# reI = torch.unsqueeze(reI, dim = 0)
# print(reI.shape)
# rescaled1 = torch.nn.functional.interpolate(reI, scale_factor = 0.5, mode = "bicubic") # 200
# rescaled2 = torch.nn.functional.interpolate(rescaled1, scale_factor = 0.5, mode = "bicubic")#100
# rescaled3 = torch.nn.functional.interpolate(rescaled2, scale_factor = 0.5, mode = "bicubic")#50

# rescaled1 = torch.squeeze(rescaled1)
# rescaled2 = torch.squeeze(rescaled2)
# rescaled3 = torch.squeeze(rescaled3)

# I = transforms.ToPILImage()
# en1 = I(rescaled1)
# en2 = I(rescaled2)
# en3 = I(rescaled3)
# en1.show()
# en2.show()
# en3.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# EXPERIMENT INFORMATION
#
#
# Verson 13: Even after 9th epoch the results seems to be consistent. The model is not learning anything. It is learning about the lightning, structures and colors very well but it's not getting the textures right(or at all). Here we started training it from 60,100 size.
